# %% [markdown]
# # forward Propagation

# %% [markdown]
# * It involves the transmission of input data through the network's layers to produce an ouput.
# * Each layer process the input using weights to that layer + activation function applied on the Z-value thus genrating the prediction.

# %% [markdown]
# ![image.png](attachment:10aa6028-21ef-4aa6-b89f-c491552c1979.png)

# %% [markdown]
# ## Layer 1

# %% [markdown]
# ![image.png](attachment:059557ea-e82b-4338-bfb9-2a82ca806437.png)
#
#
# ## Layer 2
#
# ![image.png](attachment:ee9a652b-4302-4c1f-a5c7-f16327de5afe.png)

# %% [markdown]
# ### output of layer 1
# ![image.png](attachment:c81a4305-a4e8-4e58-830e-24a257be39bd.png)
#
# ${a^{[0]}}$ is input layer

# %% [markdown]
# ${a^{[3]}}$ is the `3rd` layer or the `output` layer
